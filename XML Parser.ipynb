# %%
from zipfile import ZipFile 
from io import BytesIO
import re
from bs4 import BeautifulSoup as bs

import pandas as pd
import csv

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
# Loading ProQuest Data
files=[]
for i in range(1, 12):
  if i < 10:
    files.append('/drive/MyDrive/LDW 2021/Input/ProQuest-Datathon2021-Challenge-20210205T233945Z-00' + str(i) +'.zip')
  elif i >= 10:
    files.append('/drive/MyDrive/LDW 2021/Input/ProQuest-Datathon2021-Challenge-20210205T233945Z-0' + str(i) +'.zip')

print(files)
# Out:
# ['/drive/MyDrive/LDW 2021/ProQuest-Datathon2021-Challenge-20210205T233945Z-001.zip', '/drive/MyDrive/LDW 2021/ProQuest-Datathon2021-Challenge-20210205T233945Z-002.zip', '/drive/MyDrive/LDW 2021/ProQuest-Datathon2021-Challenge-20210205T233945Z-003.zip', '/drive/MyDrive/LDW 2021/ProQuest-Datathon2021-Challenge-20210205T233945Z-004.zip', '/drive/MyDrive/LDW 2021/ProQuest-Datathon2021-Challenge-20210205T233945Z-005.zip', '/drive/MyDrive/LDW 2021/ProQuest-Datathon2021-Challenge-20210205T233945Z-006.zip', '/drive/MyDrive/LDW 2021/ProQuest-Datathon2021-Challenge-20210205T233945Z-007.zip', '/drive/MyDrive/LDW 2021/ProQuest-Datathon2021-Challenge-20210205T233945Z-008.zip', '/drive/MyDrive/LDW 2021/ProQuest-Datathon2021-Challenge-20210205T233945Z-009.zip', '/drive/MyDrive/LDW 2021/ProQuest-Datathon2021-Challenge-20210205T233945Z-010.zip', '/drive/MyDrive/LDW 2021/ProQuest-Datathon2021-Challenge-20210205T233945Z-011.zip']

# %%
# Creating Hash Table to Extract only Advertisement Data
# dictionary with structure: { RecordID <string> : True <bool> }
# throws 'KeyError' if you try to access a RecordID that doesn't exist (meaning it's not in the ad index)
# indexDict = {}
# NOTE: I deleted last 10 lines of downloaded file because it has unrelated (meta?)data
nytFilePath = '/drive/MyDrive/LDW 2021/Input/NewYorkTimes-Advertisement-List.csv'
adwFilePath = '/drive/MyDrive/LDW 2021/Input/AtlantaDailyWorld-Advertisement-List.csv' 
with open(nytFilePath, mode='r') as nytFile:
    nytDict = {}
    reader = csv.reader(nytFile)
    nytDict = {rows[0]:True for rows in reader}

with open(adwFilePath, mode='r') as adwFile:
    adwDict = {}
    reader = csv.reader(adwFile)
    adwDict = {rows[0]:True for rows in reader}

indexDict = {**nytDict, **adwDict}
del indexDict['RecordID']

print('Number of Total Advertisements:', len(indexDict))
# Out:
# Number of Total Advertisements: 2133468

# %%
def parse_zip(zip_file):
  ad_list = list()
  counter = 0
  with ZipFile(zip_file, 'r') as zfile: 
      for name in zfile.namelist():
          if re.search(r'\.zip$', name) is not None:  # we have a zip within a zip
              print(name)
              zfiledata = BytesIO(zfile.read(name))
              with ZipFile(zfiledata) as zfile2:
                  for xml_name in zfile2.namelist():
                    counter += 1

                    if counter % 10000 == 0: print(f'{len(ad_list)} ads out of {counter} files')
                    
                    # if counter > 1000: break -> Uncomment for smaller output

                    # Check if xml file contains an advertisement; skip if does not
                    try:
                      indexDict[xml_name.split('.')[0]]
                    except KeyError:
                      continue

                    ad_obj = {}

                    # open xml file
                    xml_file = zfile2.open(xml_name)
                    content = xml_file.read()

                    # parse xml with BeautifulSoup
                    bs_content = bs(content, "xml")
                    
                    # get important fields from xml contents
                    # Record ID
                    recordid = bs_content.find('RecordID')
                    ad_obj['RecordID']=recordid.get_text()
                    
                    # Full Text
                    text = bs_content.find('FullText')
                    try:
                      ad_obj['text']=text.get_text()
                    except:
                      ad_obj['text']=None
                    
                    # Publishing Date
                    pub_date = bs_content.find('NumericPubDate')
                    ad_obj['pubDate']=pub_date.get_text()

                    # Publisher
                    publisher = bs_content.find('Publisher')
                    ad_obj['publisher']=publisher.get_text()

                    # Object Type
                    objType = bs_content.find('ObjectType')
                    ad_obj['type']=objType.get_text()

                    ad_list.append(ad_obj)

  return pd.json_normalize(ad_list)

# %%
fileCount=0
data_frames = []
for file in files:
  fileCount = fileCount + 1
  print('File Number:', fileCount)
  data_frames.append(parse_zip(file))

pd.concat(data_frames).to_csv('/drive/MyDrive/LDW 2021/Output/AdData.csv', index=False, encoding='utf-8')
# Out:
# File Number: 1
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171009184408_00001.zip
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104201106_00034.zip
# 2106 ads out of 10000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200534_00013.zip
# 4176 ads out of 20000 files
# 6253 ads out of 30000 files
# 8302 ads out of 40000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200641_00017.zip
# 10110 ads out of 50000 files
# 12141 ads out of 60000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222642_00032.zip
# 14695 ads out of 70000 files
# 17551 ads out of 80000 files
# 20740 ads out of 90000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104201000_00030.zip
# 22794 ads out of 100000 files
# 24895 ads out of 110000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200433_00012.zip
# 26979 ads out of 120000 files
# 29113 ads out of 130000 files
# 31158 ads out of 140000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200537_00014.zip
# 33183 ads out of 150000 files
# 35244 ads out of 160000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222538_00030.zip
# 37558 ads out of 170000 files
# 40703 ads out of 180000 files
# 43661 ads out of 190000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104201003_00032.zip
# 45798 ads out of 200000 files
# 47782 ads out of 210000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200644_00018.zip
# 49747 ads out of 220000 files
# 51935 ads out of 230000 files
# 54087 ads out of 240000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200538_00015.zip
# 55980 ads out of 250000 files
# 58031 ads out of 260000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104201002_00031.zip
# 60049 ads out of 270000 files
# 62024 ads out of 280000 files
# 63966 ads out of 290000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200957_00028.zip
# 66133 ads out of 300000 files
# 68185 ads out of 310000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222640_00031.zip
# 70713 ads out of 320000 files
# 73787 ads out of 330000 files
# 76653 ads out of 340000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222430_00027.zip
# 79730 ads out of 350000 files
# 82657 ads out of 360000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222104_00017.zip
# 85679 ads out of 370000 files
# 88681 ads out of 380000 files
# 91571 ads out of 390000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200959_00029.zip
# 93843 ads out of 400000 files
# 95960 ads out of 410000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104201104_00033.zip
# 98055 ads out of 420000 files
# 100094 ads out of 430000 files
# 102113 ads out of 440000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200328_00009.zip
# 104197 ads out of 450000 files
# 106187 ads out of 460000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200746_00020.zip
# 108253 ads out of 470000 files
# 110320 ads out of 480000 files
# 112269 ads out of 490000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200956_00027.zip
# 114437 ads out of 500000 files
# 116424 ads out of 510000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200640_00016.zip
# 118485 ads out of 520000 files
# 120613 ads out of 530000 files
# 122709 ads out of 540000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200854_00025.zip
# 124774 ads out of 550000 files
# 126879 ads out of 560000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222645_00033.zip
# 129209 ads out of 570000 files
# 132112 ads out of 580000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200851_00023.zip
# 134959 ads out of 590000 files
# 137058 ads out of 600000 files
# 139056 ads out of 610000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200432_00011.zip
# 141172 ads out of 620000 files
# 143328 ads out of 630000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222534_00029.zip
# 145536 ads out of 640000 files
# 148720 ads out of 650000 files
# 151657 ads out of 660000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200852_00024.zip
# 154210 ads out of 670000 files
# 156230 ads out of 680000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200745_00019.zip
# 158319 ads out of 690000 files
# 160450 ads out of 700000 files
# 162527 ads out of 710000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222955_00001.zip
# 165048 ads out of 720000 files
# 167629 ads out of 730000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200750_00022.zip
# 170079 ads out of 740000 files
# 172033 ads out of 750000 files
# 174054 ads out of 760000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200955_00026.zip
# 175975 ads out of 770000 files
# 178052 ads out of 780000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104195308_00025.zip
# 180101 ads out of 790000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222428_00026.zip
# 182679 ads out of 800000 files
# 185478 ads out of 810000 files
# 188689 ads out of 820000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222532_00028.zip
# 191675 ads out of 830000 files
# 194591 ads out of 840000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222055_00014.zip
# 197461 ads out of 850000 files
# 200419 ads out of 860000 files
# 203586 ads out of 870000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104195258_00020.zip
# 206041 ads out of 880000 files
# 208381 ads out of 890000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200431_00010.zip
# 210718 ads out of 900000 files
# 212787 ads out of 910000 files
# 214619 ads out of 920000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221845_00010.zip
# 217452 ads out of 930000 files
# 220477 ads out of 940000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222425_00025.zip
# 223673 ads out of 950000 files
# 226783 ads out of 960000 files
# 229999 ads out of 970000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222322_00024.zip
# 232999 ads out of 980000 files
# 235900 ads out of 990000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222215_00021.zip
# 239095 ads out of 1000000 files
# 242190 ads out of 1010000 files
# 245147 ads out of 1020000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222320_00023.zip
# 248258 ads out of 1030000 files
# 251261 ads out of 1040000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104195153_00017.zip
# 253951 ads out of 1050000 files
# 256264 ads out of 1060000 files
# 258582 ads out of 1070000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222318_00022.zip
# 261483 ads out of 1080000 files
# 264625 ads out of 1090000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221951_00012.zip
# 267343 ads out of 1100000 files
# 270367 ads out of 1110000 files
# 273321 ads out of 1120000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104195150_00015.zip
# 275682 ads out of 1130000 files
# 278019 ads out of 1140000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104195257_00019.zip
# 280373 ads out of 1150000 files
# 282790 ads out of 1160000 files
# 285062 ads out of 1170000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200119_00003.zip
# 287159 ads out of 1180000 files
# 289261 ads out of 1190000 files
# File Number: 2
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222212_00020.zip
# 2924 ads out of 10000 files
# 5955 ads out of 20000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104195047_00013.zip
# 8630 ads out of 30000 files
# 11044 ads out of 40000 files
# 13244 ads out of 50000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104194940_00008.zip
# 15409 ads out of 60000 files
# 17749 ads out of 70000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222107_00018.zip
# 20449 ads out of 80000 files
# 23361 ads out of 90000 files
# 26598 ads out of 100000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104195305_00023.zip
# 28986 ads out of 110000 files
# 31532 ads out of 120000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104195152_00016.zip
# 33847 ads out of 130000 files
# 36044 ads out of 140000 files
# 38356 ads out of 150000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222110_00019.zip
# 41224 ads out of 160000 files
# 44075 ads out of 170000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222057_00015.zip
# 47128 ads out of 180000 files
# 50109 ads out of 190000 files
# 53254 ads out of 200000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200118_00002.zip
# 55273 ads out of 210000 files
# 57291 ads out of 220000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221953_00013.zip
# 59621 ads out of 230000 files
# 62669 ads out of 240000 files
# 65728 ads out of 250000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006222001_00016.zip
# 68763 ads out of 260000 files
# 71645 ads out of 270000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200326_00008.zip
# 74436 ads out of 280000 files
# 76540 ads out of 290000 files
# 78605 ads out of 300000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200325_00007.zip
# 80709 ads out of 310000 files
# 82763 ads out of 320000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200220_00004.zip
# 84777 ads out of 330000 files
# 86804 ads out of 340000 files
# 88828 ads out of 350000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200223_00006.zip
# 90922 ads out of 360000 files
# 93034 ads out of 370000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200017_00001.zip
# 95076 ads out of 380000 files
# 97255 ads out of 390000 files
# 99390 ads out of 400000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104195306_00024.zip
# 101876 ads out of 410000 files
# 104378 ads out of 420000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200222_00005.zip
# 106727 ads out of 430000 files
# 108776 ads out of 440000 files
# 110972 ads out of 450000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104194942_00010.zip
# 113311 ads out of 460000 files
# 115588 ads out of 470000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104195259_00021.zip
# 117757 ads out of 480000 files
# 120147 ads out of 490000 files
# 122656 ads out of 500000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221844_00047.zip
# 124368 ads out of 510000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104195202_00022.zip
# 126675 ads out of 520000 files
# 129025 ads out of 530000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104195154_00018.zip
# 131416 ads out of 540000 files
# 133694 ads out of 550000 files
# 136076 ads out of 560000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221736_00007.zip
# 139150 ads out of 570000 files
# 142254 ads out of 580000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104195048_00014.zip
# 145050 ads out of 590000 files
# 147521 ads out of 600000 files
# 149807 ads out of 610000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104195044_00012.zip
# 151919 ads out of 620000 files
# 154244 ads out of 630000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221631_00042.zip
# 156270 ads out of 640000 files
# 158065 ads out of 650000 files
# 159954 ads out of 660000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104194943_00011.zip
# 162198 ads out of 670000 files
# 164511 ads out of 680000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221522_00039.zip
# 166397 ads out of 690000 files
# 168297 ads out of 700000 files
# 170206 ads out of 710000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104194941_00009.zip
# 172537 ads out of 720000 files
# 174756 ads out of 730000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104194835_00006.zip
# 176985 ads out of 740000 files
# 179288 ads out of 750000 files
# 181601 ads out of 760000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221741_00046.zip
# 183572 ads out of 770000 files
# 185625 ads out of 780000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104194838_00007.zip
# 187808 ads out of 790000 files
# 189929 ads out of 800000 files
# 192334 ads out of 810000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104194834_00005.zip
# 194611 ads out of 820000 files
# 196760 ads out of 830000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104194732_00004.zip
# 199025 ads out of 840000 files
# 201309 ads out of 850000 files
# 203507 ads out of 860000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104194630_00002.zip
# 205801 ads out of 870000 files
# 208055 ads out of 880000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104194631_00003.zip
# 210207 ads out of 890000 files
# 212584 ads out of 900000 files
# 214765 ads out of 910000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104194529_00001.zip
# 216873 ads out of 920000 files
# 219108 ads out of 930000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221848_00011.zip
# 221661 ads out of 940000 files
# 224875 ads out of 950000 files
# 227979 ads out of 960000 files
# ProQuest-Datathon2021-Challenge/AtlantaDailyWorld/ADW_20171104200748_00021.zip
# 230080 ads out of 970000 files
# 232246 ads out of 980000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221318_00036.zip
# 234150 ads out of 990000 files
# 236244 ads out of 1000000 files
# 238007 ads out of 1010000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221739_00008.zip
# 240962 ads out of 1020000 files
# 244049 ads out of 1030000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221738_00045.zip
# 246638 ads out of 1040000 files
# 248521 ads out of 1050000 files
# 250311 ads out of 1060000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221742_00009.zip
# 253113 ads out of 1070000 files
# 255968 ads out of 1080000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221633_00043.zip
# 258506 ads out of 1090000 files
# 260424 ads out of 1100000 files
# 262431 ads out of 1110000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221735_00044.zip
# 264613 ads out of 1120000 files
# 266313 ads out of 1130000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221629_00004.zip
# 268631 ads out of 1140000 files
# 271665 ads out of 1150000 files
# 274621 ads out of 1160000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221528_00041.zip
# 276473 ads out of 1170000 files
# 278276 ads out of 1180000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212951_00043.zip
# File Number: 3
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221634_00006.zip
# 2817 ads out of 10000 files
# 5839 ads out of 20000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221632_00005.zip
# 8745 ads out of 30000 files
# 11617 ads out of 40000 files
# 14578 ads out of 50000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221524_00002.zip
# 17587 ads out of 60000 files
# 20559 ads out of 70000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221421_00001.zip
# 23685 ads out of 80000 files
# 26642 ads out of 90000 files
# 29429 ads out of 100000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221527_00003.zip
# 32318 ads out of 110000 files
# 35634 ads out of 120000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221526_00040.zip
# 38460 ads out of 130000 files
# 40460 ads out of 140000 files
# 42323 ads out of 150000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221419_00037.zip
# 44380 ads out of 160000 files
# 46161 ads out of 170000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221110_00030.zip
# 47910 ads out of 180000 files
# 49794 ads out of 190000 files
# 51760 ads out of 200000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221420_00038.zip
# 54032 ads out of 210000 files
# 56091 ads out of 220000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220754_00019.zip
# 57956 ads out of 230000 files
# 59877 ads out of 240000 files
# 61710 ads out of 250000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221005_00027.zip
# 63509 ads out of 260000 files
# 65315 ads out of 270000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220646_00015.zip
# 67464 ads out of 280000 files
# 69312 ads out of 290000 files
# 71163 ads out of 300000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221317_00035.zip
# 72910 ads out of 310000 files
# 74894 ads out of 320000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221212_00032.zip
# 77243 ads out of 330000 files
# 79364 ads out of 340000 files
# 81209 ads out of 350000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221214_00033.zip
# 83096 ads out of 360000 files
# 85016 ads out of 370000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221315_00034.zip
# 86917 ads out of 380000 files
# 88789 ads out of 390000 files
# 90662 ads out of 400000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221107_00029.zip
# 92470 ads out of 410000 files
# 94319 ads out of 420000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221106_00028.zip
# 96304 ads out of 430000 files
# 98144 ads out of 440000 files
# 100010 ads out of 450000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221211_00031.zip
# 101915 ads out of 460000 files
# 103980 ads out of 470000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221002_00026.zip
# 105977 ads out of 480000 files
# 108229 ads out of 490000 files
# 110215 ads out of 500000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215906_00043.zip
# 112169 ads out of 510000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220648_00016.zip
# 114055 ads out of 520000 files
# 116051 ads out of 530000 files
# 117930 ads out of 540000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220856_00021.zip
# 119824 ads out of 550000 files
# 121594 ads out of 560000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220645_00014.zip
# 123355 ads out of 570000 files
# 125069 ads out of 580000 files
# 127057 ads out of 590000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006221001_00025.zip
# 128862 ads out of 600000 files
# 130892 ads out of 610000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220959_00023.zip
# 133060 ads out of 620000 files
# 134918 ads out of 630000 files
# 136878 ads out of 640000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220900_00024.zip
# 138707 ads out of 650000 files
# 140518 ads out of 660000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220326_00007.zip
# 142485 ads out of 670000 files
# 144348 ads out of 680000 files
# 146081 ads out of 690000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220857_00022.zip
# 148268 ads out of 700000 files
# 150278 ads out of 710000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220434_00009.zip
# 152067 ads out of 720000 files
# 153924 ads out of 730000 files
# 155763 ads out of 740000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220855_00020.zip
# 157632 ads out of 750000 files
# 159677 ads out of 760000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220751_00018.zip
# 161522 ads out of 770000 files
# 163447 ads out of 780000 files
# 165301 ads out of 790000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220750_00017.zip
# 167118 ads out of 800000 files
# 169192 ads out of 810000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220538_00011.zip
# 170862 ads out of 820000 files
# 172721 ads out of 830000 files
# 174668 ads out of 840000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220543_00013.zip
# 176568 ads out of 850000 files
# 178414 ads out of 860000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220436_00010.zip
# 180354 ads out of 870000 files
# 182113 ads out of 880000 files
# 183980 ads out of 890000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220542_00012.zip
# 185859 ads out of 900000 files
# 187685 ads out of 910000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214501_00044.zip
# 190459 ads out of 920000 files
# 194309 ads out of 930000 files
# File Number: 4
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220330_00008.zip
# 1858 ads out of 10000 files
# 3856 ads out of 20000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220323_00006.zip
# 5728 ads out of 30000 files
# 7628 ads out of 40000 files
# 9646 ads out of 50000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220220_00005.zip
# 11902 ads out of 60000 files
# 13714 ads out of 70000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220217_00004.zip
# 15593 ads out of 80000 files
# 17449 ads out of 90000 files
# 19297 ads out of 100000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220114_00003.zip
# 21273 ads out of 110000 files
# 23216 ads out of 120000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215444_00027.zip
# 25098 ads out of 130000 files
# 27062 ads out of 140000 files
# 28936 ads out of 150000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215905_00042.zip
# 30938 ads out of 160000 files
# 32859 ads out of 170000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220007_00001.zip
# 34617 ads out of 180000 files
# 36577 ads out of 190000 files
# 38592 ads out of 200000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215803_00040.zip
# 40380 ads out of 210000 files
# 42288 ads out of 220000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006220112_00002.zip
# 44459 ads out of 230000 files
# 46406 ads out of 240000 files
# 48226 ads out of 250000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215904_00041.zip
# 50305 ads out of 260000 files
# 52210 ads out of 270000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215801_00039.zip
# 54118 ads out of 280000 files
# 56107 ads out of 290000 files
# 57998 ads out of 300000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215758_00036.zip
# 59885 ads out of 310000 files
# 61610 ads out of 320000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215759_00037.zip
# 63438 ads out of 330000 files
# 65356 ads out of 340000 files
# 67261 ads out of 350000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215800_00038.zip
# 69148 ads out of 360000 files
# 70961 ads out of 370000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215755_00035.zip
# 72960 ads out of 380000 files
# 74792 ads out of 390000 files
# 76701 ads out of 400000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215653_00033.zip
# 78738 ads out of 410000 files
# 80737 ads out of 420000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215654_00034.zip
# 82548 ads out of 430000 files
# 84354 ads out of 440000 files
# 86151 ads out of 450000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215446_00028.zip
# 88089 ads out of 460000 files
# 90004 ads out of 470000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215129_00018.zip
# 91821 ads out of 480000 files
# 93764 ads out of 490000 files
# 95611 ads out of 500000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215447_00029.zip
# 97508 ads out of 510000 files
# 99377 ads out of 520000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215548_00030.zip
# 101318 ads out of 530000 files
# 103177 ads out of 540000 files
# 105150 ads out of 550000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215343_00026.zip
# 106988 ads out of 560000 files
# 108894 ads out of 570000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215552_00032.zip
# 110804 ads out of 580000 files
# 112623 ads out of 590000 files
# 114511 ads out of 600000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214711_00007.zip
# 116452 ads out of 610000 files
# 118414 ads out of 620000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215340_00024.zip
# 120445 ads out of 630000 files
# 122369 ads out of 640000 files
# 124261 ads out of 650000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215025_00016.zip
# 126059 ads out of 660000 files
# 127945 ads out of 670000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214609_00005.zip
# 129819 ads out of 680000 files
# 131693 ads out of 690000 files
# 133741 ads out of 700000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214606_00003.zip
# 135660 ads out of 710000 files
# 137531 ads out of 720000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215238_00023.zip
# 139505 ads out of 730000 files
# 141491 ads out of 740000 files
# 143448 ads out of 750000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214459_00043.zip
# 147078 ads out of 760000 files
# 150960 ads out of 770000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215342_00025.zip
# 153711 ads out of 780000 files
# 155606 ads out of 790000 files
# 157522 ads out of 800000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215235_00022.zip
# 159409 ads out of 810000 files
# 161293 ads out of 820000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215132_00020.zip
# 163164 ads out of 830000 files
# 165169 ads out of 840000 files
# 167100 ads out of 850000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214920_00012.zip
# 169049 ads out of 860000 files
# 170930 ads out of 870000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215027_00017.zip
# 172770 ads out of 880000 files
# 174697 ads out of 890000 files
# 176537 ads out of 900000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215130_00019.zip
# 178438 ads out of 910000 files
# 180281 ads out of 920000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215234_00021.zip
# 182320 ads out of 930000 files
# 184295 ads out of 940000 files
# 186123 ads out of 950000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214922_00014.zip
# 188000 ads out of 960000 files
# 189840 ads out of 970000 files
# File Number: 5
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215023_00015.zip
# 1893 ads out of 10000 files
# 3859 ads out of 20000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214149_00035.zip
# 6542 ads out of 30000 files
# 10277 ads out of 40000 files
# 13802 ads out of 50000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214818_00011.zip
# 15828 ads out of 60000 files
# 17771 ads out of 70000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213728_00023.zip
# 20758 ads out of 80000 files
# 24441 ads out of 90000 files
# 28345 ads out of 100000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214144_00033.zip
# 32136 ads out of 110000 files
# 35935 ads out of 120000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214921_00013.zip
# 38520 ads out of 130000 files
# 40430 ads out of 140000 files
# 42255 ads out of 150000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214355_00040.zip
# 45965 ads out of 160000 files
# 49681 ads out of 170000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214814_00009.zip
# 52295 ads out of 180000 files
# 54253 ads out of 190000 files
# 56133 ads out of 200000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214251_00037.zip
# 59954 ads out of 210000 files
# 63768 ads out of 220000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214815_00010.zip
# 66823 ads out of 230000 files
# 68768 ads out of 240000 files
# 70698 ads out of 250000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213832_00025.zip
# 74544 ads out of 260000 files
# 78374 ads out of 270000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214710_00006.zip
# 80923 ads out of 280000 files
# 82774 ads out of 290000 files
# 84666 ads out of 300000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214712_00008.zip
# 86571 ads out of 310000 files
# 88500 ads out of 320000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214608_00004.zip
# 90304 ads out of 330000 files
# 92249 ads out of 340000 files
# 94265 ads out of 350000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214040_00031.zip
# 97903 ads out of 360000 files
# 101308 ads out of 370000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213621_00019.zip
# 104887 ads out of 380000 files
# 108415 ads out of 390000 files
# 112229 ads out of 400000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214400_00001.zip
# 114107 ads out of 410000 files
# 116088 ads out of 420000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214505_00002.zip
# 117995 ads out of 430000 files
# 119774 ads out of 440000 files
# 121580 ads out of 450000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214038_00030.zip
# 125171 ads out of 460000 files
# 128841 ads out of 470000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214458_00042.zip
# 132907 ads out of 480000 files
# 136715 ads out of 490000 files
# 140105 ads out of 500000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213414_00014.zip
# 143866 ads out of 510000 files
# 147427 ads out of 520000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214356_00041.zip
# 151167 ads out of 530000 files
# 154561 ads out of 540000 files
# 157966 ads out of 550000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214252_00038.zip
# 161680 ads out of 560000 files
# 165257 ads out of 570000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213624_00020.zip
# 168956 ads out of 580000 files
# 172770 ads out of 590000 files
# 176413 ads out of 600000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214353_00039.zip
# 180140 ads out of 610000 files
# 183863 ads out of 620000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213830_00024.zip
# 187267 ads out of 630000 files
# 190888 ads out of 640000 files
# 194358 ads out of 650000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214250_00036.zip
# 198139 ads out of 660000 files
# 202095 ads out of 670000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213726_00022.zip
# 206029 ads out of 680000 files
# 209613 ads out of 690000 files
# 213282 ads out of 700000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214145_00034.zip
# 217007 ads out of 710000 files
# 220438 ads out of 720000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213306_00009.zip
# 224166 ads out of 730000 files
# 227870 ads out of 740000 files
# 231670 ads out of 750000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006214043_00032.zip
# 235615 ads out of 760000 files
# 239496 ads out of 770000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213937_00029.zip
# 243358 ads out of 780000 files
# 247096 ads out of 790000 files
# 250871 ads out of 800000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213936_00028.zip
# 254383 ads out of 810000 files
# 258256 ads out of 820000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213934_00027.zip
# 261938 ads out of 830000 files
# 265553 ads out of 840000 files
# 269177 ads out of 850000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213833_00026.zip
# 273075 ads out of 860000 files
# 276880 ads out of 870000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213725_00021.zip
# 280476 ads out of 880000 files
# 284119 ads out of 890000 files
# 287897 ads out of 900000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213620_00018.zip
# 291481 ads out of 910000 files
# 295517 ads out of 920000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213057_00002.zip
# 299343 ads out of 930000 files
# 302819 ads out of 940000 files
# 306648 ads out of 950000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213518_00017.zip
# 310399 ads out of 960000 files
# 313976 ads out of 970000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213517_00016.zip
# 317541 ads out of 980000 files
# 321155 ads out of 990000 files
# 324716 ads out of 1000000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212847_00040.zip
# 327387 ads out of 1010000 files
# 330218 ads out of 1020000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210043_00042.zip
# 332006 ads out of 1030000 files
# File Number: 6
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212950_00042.zip
# 2308 ads out of 10000 files
# 5221 ads out of 20000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213413_00013.zip
# 8843 ads out of 30000 files
# 12648 ads out of 40000 files
# 16212 ads out of 50000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212849_00041.zip
# 19083 ads out of 60000 files
# 22401 ads out of 70000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212537_00032.zip
# 25015 ads out of 80000 files
# 27687 ads out of 90000 files
# 30459 ads out of 100000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213515_00015.zip
# 33780 ads out of 110000 files
# 37619 ads out of 120000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213311_00011.zip
# 41400 ads out of 130000 files
# 45213 ads out of 140000 files
# 48956 ads out of 150000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213307_00010.zip
# 52692 ads out of 160000 files
# 56422 ads out of 170000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213412_00012.zip
# 60206 ads out of 180000 files
# 63603 ads out of 190000 files
# 67080 ads out of 200000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213203_00007.zip
# 70776 ads out of 210000 files
# 74518 ads out of 220000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006215550_00031.zip
# 77257 ads out of 230000 files
# 79162 ads out of 240000 files
# 81081 ads out of 250000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213158_00003.zip
# 84999 ads out of 260000 files
# 88648 ads out of 270000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212330_00027.zip
# 92064 ads out of 280000 files
# 94750 ads out of 290000 files
# 97777 ads out of 300000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213204_00008.zip
# 101517 ads out of 310000 files
# 105389 ads out of 320000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213202_00006.zip
# 109245 ads out of 330000 files
# 112865 ads out of 340000 files
# 116469 ads out of 350000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212535_00031.zip
# 119956 ads out of 360000 files
# 122735 ads out of 370000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213101_00005.zip
# 126289 ads out of 380000 files
# 130090 ads out of 390000 files
# 133678 ads out of 400000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213100_00004.zip
# 137528 ads out of 410000 files
# 141292 ads out of 420000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006213053_00001.zip
# 144957 ads out of 430000 files
# 148627 ads out of 440000 files
# 151889 ads out of 450000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212846_00039.zip
# 154583 ads out of 460000 files
# 157632 ads out of 470000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212745_00038.zip
# 160968 ads out of 480000 files
# 163717 ads out of 490000 files
# 166563 ads out of 500000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212643_00036.zip
# 168964 ads out of 510000 files
# 171709 ads out of 520000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212744_00037.zip
# 175489 ads out of 530000 files
# 178400 ads out of 540000 files
# 181350 ads out of 550000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212641_00035.zip
# 184305 ads out of 560000 files
# 186853 ads out of 570000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212433_00029.zip
# 189768 ads out of 580000 files
# 192339 ads out of 590000 files
# 194998 ads out of 600000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212640_00034.zip
# 197799 ads out of 610000 files
# 200476 ads out of 620000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212539_00033.zip
# 203286 ads out of 630000 files
# 206253 ads out of 640000 files
# 209135 ads out of 650000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212221_00022.zip
# 211878 ads out of 660000 files
# 214644 ads out of 670000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212115_00019.zip
# 217913 ads out of 680000 files
# 220581 ads out of 690000 files
# 223528 ads out of 700000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212434_00030.zip
# 226300 ads out of 710000 files
# 229073 ads out of 720000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212431_00028.zip
# 231581 ads out of 730000 files
# 234573 ads out of 740000 files
# 237497 ads out of 750000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211443_00001.zip
# 240134 ads out of 760000 files
# 242709 ads out of 770000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212329_00026.zip
# 246321 ads out of 780000 files
# 249199 ads out of 790000 files
# 251664 ads out of 800000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212327_00025.zip
# 254613 ads out of 810000 files
# 257997 ads out of 820000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212226_00024.zip
# 260104 ads out of 830000 files
# 263132 ads out of 840000 files
# 265783 ads out of 850000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212117_00020.zip
# 268922 ads out of 860000 files
# 271780 ads out of 870000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212120_00021.zip
# 274618 ads out of 880000 files
# 277447 ads out of 890000 files
# 279913 ads out of 900000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212223_00023.zip
# 282450 ads out of 910000 files
# 285283 ads out of 920000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212013_00018.zip
# 289185 ads out of 930000 files
# 292007 ads out of 940000 files
# 294788 ads out of 950000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211805_00012.zip
# 297670 ads out of 960000 files
# 300575 ads out of 970000 files
# File Number: 7
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212011_00017.zip
# 2650 ads out of 10000 files
# 5481 ads out of 20000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211907_00014.zip
# 8368 ads out of 30000 files
# 11210 ads out of 40000 files
# 13993 ads out of 50000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211908_00015.zip
# 16816 ads out of 60000 files
# 20100 ads out of 70000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006212009_00016.zip
# 22960 ads out of 80000 files
# 26074 ads out of 90000 files
# 29001 ads out of 100000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211906_00013.zip
# 31790 ads out of 110000 files
# 34420 ads out of 120000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211550_00043.zip
# 35993 ads out of 130000 files
# 37242 ads out of 140000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211441_00039.zip
# 38431 ads out of 150000 files
# 39687 ads out of 160000 files
# 40960 ads out of 170000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211758_00008.zip
# 43677 ads out of 180000 files
# 46533 ads out of 190000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211803_00011.zip
# 49003 ads out of 200000 files
# 51886 ads out of 210000 files
# 54583 ads out of 220000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211801_00010.zip
# 56910 ads out of 230000 files
# 59696 ads out of 240000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211757_00007.zip
# 62329 ads out of 250000 files
# 65193 ads out of 260000 files
# 67914 ads out of 270000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211700_00009.zip
# 70674 ads out of 280000 files
# 73689 ads out of 290000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211655_00005.zip
# 76450 ads out of 300000 files
# 79198 ads out of 310000 files
# 81983 ads out of 320000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211129_00032.zip
# 83700 ads out of 330000 files
# 84869 ads out of 340000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211653_00004.zip
# 86603 ads out of 350000 files
# 89430 ads out of 360000 files
# 92020 ads out of 370000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211656_00006.zip
# 95525 ads out of 380000 files
# 98672 ads out of 390000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211551_00003.zip
# 101738 ads out of 400000 files
# 104165 ads out of 410000 files
# 106882 ads out of 420000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211549_00002.zip
# 109979 ads out of 430000 files
# 112735 ads out of 440000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211548_00042.zip
# 115106 ads out of 450000 files
# 116401 ads out of 460000 files
# 117634 ads out of 470000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211444_00041.zip
# 118747 ads out of 480000 files
# 120005 ads out of 490000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210712_00021.zip
# 121243 ads out of 500000 files
# 122552 ads out of 510000 files
# 123767 ads out of 520000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211442_00040.zip
# 125031 ads out of 530000 files
# 126336 ads out of 540000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211236_00035.zip
# 127565 ads out of 550000 files
# 128839 ads out of 560000 files
# 130132 ads out of 570000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210501_00013.zip
# 131437 ads out of 580000 files
# 132717 ads out of 590000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211339_00037.zip
# 133924 ads out of 600000 files
# 135191 ads out of 610000 files
# 136388 ads out of 620000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211340_00038.zip
# 137603 ads out of 630000 files
# 138900 ads out of 640000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210354_00008.zip
# 140096 ads out of 650000 files
# 141294 ads out of 660000 files
# 142436 ads out of 670000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211337_00036.zip
# 143757 ads out of 680000 files
# 144973 ads out of 690000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211233_00033.zip
# 146313 ads out of 700000 files
# 147580 ads out of 710000 files
# 148854 ads out of 720000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211128_00031.zip
# 150037 ads out of 730000 files
# 151291 ads out of 740000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210400_00012.zip
# 152459 ads out of 750000 files
# 153623 ads out of 760000 files
# 154813 ads out of 770000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211234_00034.zip
# 156105 ads out of 780000 files
# 157315 ads out of 790000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210358_00010.zip
# 158568 ads out of 800000 files
# 159797 ads out of 810000 files
# 161082 ads out of 820000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210921_00026.zip
# 162368 ads out of 830000 files
# 163592 ads out of 840000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211023_00028.zip
# 164948 ads out of 850000 files
# 166149 ads out of 860000 files
# 167483 ads out of 870000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210355_00009.zip
# 168668 ads out of 880000 files
# 169866 ads out of 890000 files
# File Number: 8
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211025_00029.zip
# 1298 ads out of 10000 files
# 2617 ads out of 20000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210040_00001.zip
# 3872 ads out of 30000 files
# 5183 ads out of 40000 files
# 6382 ads out of 50000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210919_00025.zip
# 7642 ads out of 60000 files
# 8888 ads out of 70000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210922_00027.zip
# 10101 ads out of 80000 files
# 11416 ads out of 90000 files
# 12631 ads out of 100000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006211127_00030.zip
# 13912 ads out of 110000 files
# 15198 ads out of 120000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210818_00024.zip
# 16557 ads out of 130000 files
# 17791 ads out of 140000 files
# 19031 ads out of 150000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205939_00041.zip
# 20306 ads out of 160000 files
# 21553 ads out of 170000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210815_00022.zip
# 22842 ads out of 180000 files
# 24105 ads out of 190000 files
# 25383 ads out of 200000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210816_00023.zip
# 26726 ads out of 210000 files
# 27946 ads out of 220000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210710_00019.zip
# 29215 ads out of 230000 files
# 30446 ads out of 240000 files
# 31630 ads out of 250000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210711_00020.zip
# 32929 ads out of 260000 files
# 34210 ads out of 270000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210608_00018.zip
# 35546 ads out of 280000 files
# 36789 ads out of 290000 files
# 37972 ads out of 300000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210607_00017.zip
# 39287 ads out of 310000 files
# 40533 ads out of 320000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205834_00037.zip
# 41667 ads out of 330000 files
# 42939 ads out of 340000 files
# 44152 ads out of 350000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210606_00016.zip
# 45345 ads out of 360000 files
# 46516 ads out of 370000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210502_00014.zip
# 47750 ads out of 380000 files
# 49058 ads out of 390000 files
# 50314 ads out of 400000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210504_00015.zip
# 51617 ads out of 410000 files
# 52918 ads out of 420000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205629_00033.zip
# 54150 ads out of 430000 files
# 55338 ads out of 440000 files
# 56754 ads out of 450000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210459_00011.zip
# 58000 ads out of 460000 files
# 59269 ads out of 470000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205938_00040.zip
# 60609 ads out of 480000 files
# 61838 ads out of 490000 files
# 63202 ads out of 500000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205521_00028.zip
# 64356 ads out of 510000 files
# 65665 ads out of 520000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210252_00007.zip
# 66876 ads out of 530000 files
# 68114 ads out of 540000 files
# 69275 ads out of 550000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210251_00006.zip
# 70604 ads out of 560000 files
# 71843 ads out of 570000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205836_00038.zip
# 73093 ads out of 580000 files
# 74321 ads out of 590000 files
# 75556 ads out of 600000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205210_00021.zip
# 76818 ads out of 610000 files
# 78240 ads out of 620000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210148_00004.zip
# 79539 ads out of 630000 files
# 80762 ads out of 640000 files
# 81999 ads out of 650000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210045_00002.zip
# 83251 ads out of 660000 files
# 84446 ads out of 670000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210146_00003.zip
# 85711 ads out of 680000 files
# 86890 ads out of 690000 files
# 88212 ads out of 700000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205058_00014.zip
# 89519 ads out of 710000 files
# 90789 ads out of 720000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205731_00034.zip
# 91993 ads out of 730000 files
# 93224 ads out of 740000 files
# 94450 ads out of 750000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006210249_00005.zip
# 95721 ads out of 760000 files
# 97058 ads out of 770000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205937_00039.zip
# 98162 ads out of 780000 files
# 99425 ads out of 790000 files
# 100607 ads out of 800000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204748_00008.zip
# 102019 ads out of 810000 files
# 103402 ads out of 820000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204747_00007.zip
# 104645 ads out of 830000 files
# 105916 ads out of 840000 files
# 107112 ads out of 850000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204852_00010.zip
# 108279 ads out of 860000 files
# 109446 ads out of 870000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006201713_00009.zip
# 110711 ads out of 880000 files
# File Number: 9
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205833_00036.zip
# 1266 ads out of 10000 files
# 2460 ads out of 20000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205732_00035.zip
# 3772 ads out of 30000 files
# 5078 ads out of 40000 files
# 6453 ads out of 50000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205420_00027.zip
# 7649 ads out of 60000 files
# 8927 ads out of 70000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205628_00032.zip
# 10121 ads out of 80000 files
# 11358 ads out of 90000 files
# 12707 ads out of 100000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205526_00030.zip
# 13963 ads out of 110000 files
# 15236 ads out of 120000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205523_00029.zip
# 16416 ads out of 130000 files
# 17693 ads out of 140000 files
# 19056 ads out of 150000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205418_00026.zip
# 20342 ads out of 160000 files
# 21555 ads out of 170000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205105_00018.zip
# 22834 ads out of 180000 files
# 23992 ads out of 190000 files
# 25261 ads out of 200000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204436_00041.zip
# 26784 ads out of 210000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205316_00024.zip
# 28107 ads out of 220000 files
# 29322 ads out of 230000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205212_00022.zip
# 30565 ads out of 240000 files
# 31834 ads out of 250000 files
# 33104 ads out of 260000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205417_00025.zip
# 34445 ads out of 270000 files
# 35652 ads out of 280000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205627_00031.zip
# 36949 ads out of 290000 files
# 38229 ads out of 300000 files
# 39484 ads out of 310000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205314_00023.zip
# 40712 ads out of 320000 files
# 42041 ads out of 330000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205103_00017.zip
# 43278 ads out of 340000 files
# 44389 ads out of 350000 files
# 45694 ads out of 360000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205107_00019.zip
# 46884 ads out of 370000 files
# 48146 ads out of 380000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205209_00020.zip
# 49548 ads out of 390000 files
# 50844 ads out of 400000 files
# 52090 ads out of 410000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205001_00016.zip
# 53325 ads out of 420000 files
# 54677 ads out of 430000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006205059_00015.zip
# 56170 ads out of 440000 files
# 57484 ads out of 450000 files
# 58764 ads out of 460000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204330_00036.zip
# 60165 ads out of 470000 files
# 61575 ads out of 480000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204957_00013.zip
# 62921 ads out of 490000 files
# 64175 ads out of 500000 files
# 65223 ads out of 510000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204956_00012.zip
# 66548 ads out of 520000 files
# 67839 ads out of 530000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204124_00033.zip
# 69241 ads out of 540000 files
# 70688 ads out of 550000 files
# 72022 ads out of 560000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203915_00027.zip
# 73396 ads out of 570000 files
# 74864 ads out of 580000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204955_00011.zip
# 76229 ads out of 590000 files
# 77567 ads out of 600000 files
# 78901 ads out of 610000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204850_00009.zip
# 80332 ads out of 620000 files
# 81500 ads out of 630000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204746_00006.zip
# 82707 ads out of 640000 files
# 84102 ads out of 650000 files
# 85416 ads out of 660000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204644_00004.zip
# 86792 ads out of 670000 files
# 88062 ads out of 680000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204017_00029.zip
# 89224 ads out of 690000 files
# 90497 ads out of 700000 files
# 91933 ads out of 710000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204642_00003.zip
# 93239 ads out of 720000 files
# 94509 ads out of 730000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204645_00005.zip
# 95841 ads out of 740000 files
# 97099 ads out of 750000 files
# 98369 ads out of 760000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204540_00002.zip
# 99761 ads out of 770000 files
# 100948 ads out of 780000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204434_00039.zip
# 102279 ads out of 790000 files
# 103668 ads out of 800000 files
# 105117 ads out of 810000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204537_00001.zip
# 106380 ads out of 820000 files
# 107685 ads out of 830000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204435_00040.zip
# 109162 ads out of 840000 files
# 110469 ads out of 850000 files
# 111901 ads out of 860000 files
# File Number: 10
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204333_00038.zip
# 1276 ads out of 10000 files
# 2667 ads out of 20000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204331_00037.zip
# 4017 ads out of 30000 files
# 5545 ads out of 40000 files
# 6923 ads out of 50000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203454_00014.zip
# 8417 ads out of 60000 files
# 9809 ads out of 70000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204228_00034.zip
# 11192 ads out of 80000 files
# 12534 ads out of 90000 files
# 13906 ads out of 100000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204229_00035.zip
# 15179 ads out of 110000 files
# 16610 ads out of 120000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204123_00032.zip
# 17965 ads out of 130000 files
# 19418 ads out of 140000 files
# 20816 ads out of 150000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204020_00030.zip
# 22167 ads out of 160000 files
# 23676 ads out of 170000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203706_00022.zip
# 25088 ads out of 180000 files
# 26432 ads out of 190000 files
# 27731 ads out of 200000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203916_00028.zip
# 29195 ads out of 210000 files
# 30442 ads out of 220000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203913_00026.zip
# 31857 ads out of 230000 files
# 33296 ads out of 240000 files
# 34681 ads out of 250000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203809_00023.zip
# 36043 ads out of 260000 files
# 37448 ads out of 270000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006204122_00031.zip
# 38904 ads out of 280000 files
# 40217 ads out of 290000 files
# 41541 ads out of 300000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203243_00007.zip
# 42877 ads out of 310000 files
# 44278 ads out of 320000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203810_00024.zip
# 45573 ads out of 330000 files
# 46876 ads out of 340000 files
# 48269 ads out of 350000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203601_00019.zip
# 49640 ads out of 360000 files
# 50944 ads out of 370000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203705_00021.zip
# 52254 ads out of 380000 files
# 53605 ads out of 390000 files
# 55015 ads out of 400000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203812_00025.zip
# 56320 ads out of 410000 files
# 57680 ads out of 420000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203452_00012.zip
# 59198 ads out of 430000 files
# 60654 ads out of 440000 files
# 62107 ads out of 450000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203604_00020.zip
# 63453 ads out of 460000 files
# 64817 ads out of 470000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203347_00010.zip
# 66157 ads out of 480000 files
# 67494 ads out of 490000 files
# 68898 ads out of 500000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203555_00015.zip
# 70206 ads out of 510000 files
# 71545 ads out of 520000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203558_00017.zip
# 72910 ads out of 530000 files
# 74338 ads out of 540000 files
# 75769 ads out of 550000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203600_00018.zip
# 77022 ads out of 560000 files
# 78378 ads out of 570000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203453_00013.zip
# 79595 ads out of 580000 files
# 80921 ads out of 590000 files
# 82327 ads out of 600000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203557_00016.zip
# 83695 ads out of 610000 files
# 85064 ads out of 620000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203141_00005.zip
# 86508 ads out of 630000 files
# 87815 ads out of 640000 files
# 89188 ads out of 650000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006201506_00004.zip
# 90739 ads out of 660000 files
# 92266 ads out of 670000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006201612_00008.zip
# 93778 ads out of 680000 files
# 95367 ads out of 690000 files
# 96882 ads out of 700000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203140_00004.zip
# 98247 ads out of 710000 files
# 99643 ads out of 720000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203350_00011.zip
# 101025 ads out of 730000 files
# 102527 ads out of 740000 files
# 104036 ads out of 750000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203346_00009.zip
# 105292 ads out of 760000 files
# 106722 ads out of 770000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203244_00008.zip
# 108084 ads out of 780000 files
# 109514 ads out of 790000 files
# 110914 ads out of 800000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203142_00006.zip
# 112124 ads out of 810000 files
# 113423 ads out of 820000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006201508_00005.zip
# 114907 ads out of 830000 files
# 116387 ads out of 840000 files
# 117923 ads out of 850000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203037_00002.zip
# 119295 ads out of 860000 files
# 120816 ads out of 870000 files
# File Number: 11
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006202933_00001.zip
# 1464 ads out of 10000 files
# 2746 ads out of 20000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006201611_00007.zip
# 4243 ads out of 30000 files
# 5664 ads out of 40000 files
# 7240 ads out of 50000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006201401_00001.zip
# 8738 ads out of 60000 files
# 10248 ads out of 70000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006201402_00002.zip
# 11848 ads out of 80000 files
# 13285 ads out of 90000 files
# 14861 ads out of 100000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006201609_00006.zip
# 16291 ads out of 110000 files
# 17849 ads out of 120000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006201503_00003.zip
# 19288 ads out of 130000 files
# 20813 ads out of 140000 files
# 22359 ads out of 150000 files
# ProQuest-Datathon2021-Challenge/NewYorkTimes/NYT_20171006203038_00003.zip
# 23818 ads out of 160000 files
# 25099 ads out of 170000 files
